# %%
# pip install opencv-python
# pip install matplotlib
# pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2

# %%
#read image

image_path = ('image.jpg')
image = cv2.imread(image_path)

# %%
plt.imshow(image)

# %%
import easyocr

# %%
#instance text detector 

reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
text = reader.readtext(image)

# %%
# detect text on image
for t in text:
    bbox, txt, score = t
    pt1 = tuple(map(int, bbox[0]))
    pt2 = tuple(map(int, bbox[2]))
    cv2.rectangle(image, pt1, pt2, (0, 255, 0), 5)
    cv2.putText(image, txt, pt1 , cv2.FONT_HERSHEY_COMPLEX, 0.5, (0,0,0), 2)
    print(t)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# ([[108, 100], [196, 100], [196, 132], [108, 132]], 'OCR', 0.9999197498804463)
# ([[106.00649859892918, 53.12534453582382], [195.89309423613196, 65.08140473080032], [188.9935014010708, 99.87465546417619], [99.10690576386803, 87.91859526919968]], 'Easy', 0.9999875426292419)
